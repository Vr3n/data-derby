# %%
import pandas as pd

# %%
results_ovr = pd.read_csv("Premier-League/results2025-202691_overall-Premier-League-2025-2026.csv")

# %%
results_df = pd.read_csv("Premier-League/results2025-202691_home_away-Premier-League-2025-2026.csv")

# %%
results_ovr.head(1).T
# Out:
#                                                                   0
# rank                                                              1
# team_id                                                      squads
# team_url                        /en/squads/822bd0ba/Liverpool-Stats
# team                                                      Liverpool
# logo_url          https://cdn.ssref.net/req/202508071/tlogo/fb/m...
# games                                                             5
# wins                                                              5
# ties                                                              0
# losses                                                            0
# goals_for                                                        11
# goals_against                                                     5
# goal_diff                                                         6
# points                                                           15
# ...

# %%
squad_stats_df = pd.read_csv("Premier-League/stats_squads_standard_for-Premier-League-2025-2026.csv")
squad_stats_against_df = pd.read_csv("Premier-League/stats_squads_standard_against-Premier-League-2025-2026.csv")

# %%
squad_stats_df.head(1).T
# Out:
#                                                              0
# team_id                                                 squads
# team_url                     /en/squads/18bb7c10/Arsenal-Stats
# team                                                   Arsenal
# players_used                                                21
# avg_age                                                   25.9
# possession                                                54.6
# games                                                        5
# games_starts                                                55
# minutes                                                    450
# minutes_90s                                                5.0
# goals                                                       10
# assists                                                      7
# goals_assists                                               17
# goals_pens                                                   9
# ...

# %%
squad_stats_against_df.head(1).T
# Out:
#                                                                   0
# team_id                                                      squads
# team_url                          /en/squads/18bb7c10/Arsenal-Stats
# team                                                     vs Arsenal
# players_used_away                                                21
# avg_age_away                                                   26.4
# possession_away                                                45.4
# games_away                                                        5
# games_starts_away                                                55
# minutes_away                                                    450
# minutes_90s_away                                                5.0
# goals_away                                                        2
# assists_away                                                      1
# goals_assists_away                                                3
# ...
